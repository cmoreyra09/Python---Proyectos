# %% [markdown]
# ## Importando datos mediante una ruta correspondiente y Guardando

# %%
## En esta seccion se realizara una importacion de un dataset correspondiente pero se encuentra en una ruta

## Importacion de librerias
import pandas as pd
from tabulate import tabulate

df = pd.read_csv(r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\BBDD - No estructurada\Concursos.csv",delimiter=';')

# Ahora puedes trabajar con los datos utilizando Pandas
# Por ejemplo, puedes imprimir las primeras filas del DataFrame
df
# Out:
#    COD. TIENDA  CADENA                       LOCAL  INDICADOR    SEMANA
# 0          313  TOTTUS                   Tottus Ica      EEAA  Semana 1  \
# 1          332  TOTTUS               Tottus Chincha      EEAA  Semana 1
# 2          332  TOTTUS               Tottus Chincha      EEAA  Semana 1
# 3          332  TOTTUS               Tottus Chincha      EEAA  Semana 1
# 4          332  TOTTUS               Tottus Chincha      EEAA  Semana 1
# ..         ...     ...                          ...       ...       ...
# 57        S081   METRO            Metro El Ejercito      EEAA  Semana 4
# 58        S085   METRO                   Metro Grau      EEAA  Semana 4
# 59        S037   METRO                  Metro Balta      EEAA  Semana 4
# 60        S014   METRO             Metro Ventanilla      EEAA  Semana 4
# 61        H013   METRO  Metro Fiori - Independencia      EEAA  Semana 4
#
#           DETALLE  aw  PUNTOS Categoria            MARCA
# ...

# %%
filtro = df.loc[df['CADENA']=='TOTTUS'].head(5)
filtro
# Out:
#   COD. TIENDA  CADENA          LOCAL  INDICADOR    SEMANA        DETALLE  aw
# 0         313  TOTTUS      Tottus Ica      EEAA  Semana 1   Minicabecera   1  \
# 1         332  TOTTUS  Tottus Chincha      EEAA  Semana 1        Lateral   1
# 2         332  TOTTUS  Tottus Chincha      EEAA  Semana 1        Lateral   6
# 3         332  TOTTUS  Tottus Chincha      EEAA  Semana 1   Minicabecera   1
# 4         332  TOTTUS  Tottus Chincha      EEAA  Semana 1  Punto de Caja   2
#
#    PUNTOS Categoria          MARCA
# 0      80     ANGEL  Angel Clasico
# 1      90     ANGEL   Casino Break
# 2     540     ANGEL  Angel Clasico
# 3      80     ANGEL   Casino Break
# 4     140     ANGEL   Casino Break

# %%
## Guardar archivo en una ruta especifica

df.to_csv(r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\Test_Output_python_rout.csv", index=False)

# %%
import pandas as pd

ruta_archivo_lectura = r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\BBDD - No estructurada\Concursos.csv"
ruta_archivo_escritura = r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\BBDD - No estructurada\Test_Output_python_rout.csv"

# Leer el archivo CSV en un DataFrame
df = pd.read_csv(ruta_archivo_lectura)

# Realizar operaciones o modificaciones en el DataFrame si es necesario

# Guardar el DataFrame en la nueva ubicación
df.to_csv(ruta_archivo_escritura, index=False)
