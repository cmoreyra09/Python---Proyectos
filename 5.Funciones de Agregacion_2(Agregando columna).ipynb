# %%
import pandas as pd
from tabulate import tabulate

df = pd.read_csv(r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\BBDD - No estructurada\Makro_Ventas.csv",delimiter=";")
df.head(5) ## Salida 5 Datos
# Out:
#     Año    Mes    Semana      Fechas Cadena Departamento
# 0  2022  Abril  Semana 1  01/04/2022  Makro        Cusco  \
# 1  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 2  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 3  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 4  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
#
#                Distrito    Categoria     Marca  Codigo_Producto
# 0  San Jeronimo (Cusco)       Lejias   Sapolio          8300003  \
# 1  San Jeronimo (Cusco)       Pastas   Alianza          4300008
# 2  San Jeronimo (Cusco)      Aceites    Primor          3101013
# 3  San Jeronimo (Cusco)      Aceites    Primor          3101018
# 4  San Jeronimo (Cusco)  Detergentes  Marsella          8400550
#
#                                             Material  Unidades B2B
# 0     Lejia Sapolio Original 5000 grs 4Bot - 8300003            19  \
# 1    Fid.Alianza Codo Rayado 250 grs 20Bol - 4300008             2
# ...

# %%
## Ejercicio 1
## Se pide calcular  la venta final de forma fictisia  en este caso primero se agregar una columna cuya informacion sera 10 y se pide obtener la venta final en relacion a la nueva columna creada solo 5 registros

df['Precio_Unitario'] = 10
df['Venta']= df['Precio_Unitario'] * df['Unidades B2B']
df.head(5)
# Out:
#     Año    Mes    Semana      Fechas Cadena Departamento  \
# 0  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 1  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 2  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 3  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 4  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
#
#                Distrito    Categoria     Marca  Codigo_Producto  \
# 0  San Jeronimo (Cusco)       Lejias   Sapolio          8300003
# 1  San Jeronimo (Cusco)       Pastas   Alianza          4300008
# 2  San Jeronimo (Cusco)      Aceites    Primor          3101013
# 3  San Jeronimo (Cusco)      Aceites    Primor          3101018
# 4  San Jeronimo (Cusco)  Detergentes  Marsella          8400550
#
#                                             Material  Unidades B2B  \
# 0     Lejia Sapolio Original 5000 grs 4Bot - 8300003            19
# 1    Fid.Alianza Codo Rayado 250 grs 20Bol - 4300008             2
# ...

# %%
## Ejercicio 2 ahora crea de una variable nueva donde la operacion que se realizara es una resta

ejercico_2 = df
ejercico_2['Diferencia'] = ejercico_2['Ventas sin IGV'] - ejercico_2['Venta']
ejercico_2.sort_values(by='Diferencia',ascending=False).head(10)
# Out:
#          Año      Mes    Semana      Fechas Cadena Departamento  \
# 219085  2022  Febrero  Semana 4  24/02/2022  Makro         Lima
# 124521  2022    Enero  Semana 4  29/01/2022  Makro         Lima
# 198983  2022  Febrero  Semana 2  11/02/2022  Makro         Lima
# 214304  2022  Febrero  Semana 3  18/02/2022  Makro         Lima
# 222161  2022  Febrero  Semana 4  22/02/2022  Makro         Lima
# 122991  2022    Enero  Semana 3  21/01/2022  Makro         Lima
# 180008  2022  Febrero  Semana 1  02/02/2022  Makro         Lima
# 180843  2022  Febrero  Semana 1  03/02/2022  Makro         Lima
# 208054  2022  Febrero  Semana 2  12/02/2022  Makro         Lima
# 192130  2022  Febrero  Semana 1  07/02/2022  Makro  La Libertad
#
#                     Distrito    Categoria     Marca  Codigo_Producto  \
# 219085           Santa Anita  Detergentes  Marsella          8404702
# 124521           Santa Anita  Detergentes  Marsella          8404702
# ...

# %%
## Creacion de una tabla 

data = []

df2 = pd.DataFrame(data, columns=['Nombre', 'Edad', 'Sexo'])
df2
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Sexo]
# Index: []
