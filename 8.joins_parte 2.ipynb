# %%
import pandas as pd 
from tabulate import tabulate

df = pd.read_csv(r"C:\Users\User\OneDrive\Documentos\Archivos_Carlos\BBDD - No estructurada\Makro_Ventas.csv",delimiter=";")
df.head(5) ## Salida 5 Datos
# Out:
#     Año    Mes    Semana      Fechas Cadena Departamento
# 0  2022  Abril  Semana 1  01/04/2022  Makro        Cusco  \
# 1  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 2  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 3  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
# 4  2022  Abril  Semana 1  01/04/2022  Makro        Cusco
#
#                Distrito    Categoria     Marca  Codigo_Producto
# 0  San Jeronimo (Cusco)       Lejias   Sapolio          8300003  \
# 1  San Jeronimo (Cusco)       Pastas   Alianza          4300008
# 2  San Jeronimo (Cusco)      Aceites    Primor          3101013
# 3  San Jeronimo (Cusco)      Aceites    Primor          3101018
# 4  San Jeronimo (Cusco)  Detergentes  Marsella          8400550
#
#                                             Material  Unidades B2B
# 0     Lejia Sapolio Original 5000 grs 4Bot - 8300003            19  \
# 1    Fid.Alianza Codo Rayado 250 grs 20Bol - 4300008             2
# ...

# %%
## Ventas

Ventas = df[['Codigo_Producto','Ventas sin IGV','Unidades B2B','Peso en Toneladas']]
nueva_columna = Ventas.rename(columns={'Codigo_Producto':'Codigo'})
Ventas_1 = nueva_columna
Ventas_1
# Out:
#          Codigo  Ventas sin IGV  Unidades B2B  Peso en Toneladas
# 0       8300003          165.71            19           0.095000
# 1       4300008            2.29             2           0.000500
# 2       3101013          603.90            61           0.055876
# 3       3101018           29.57             1           0.000916
# 4       8400550            6.78             1           0.000750
# ...         ...             ...           ...                ...
# 625429  8317046            6.61             3           0.001944
# 625430  8317047            2.20             1           0.000648
# 625431  3101031          854.68            87           0.071688
# 625432  3101031          378.63            38           0.031312
# 625433  5101847           30.78            11           0.001320
#
# [625434 rows x 4 columns]

# %%
## Quitar duplicados correctos Producto
## Parte 1
Producto = df[['Codigo_Producto','Material']]
Producto_ = Producto.drop_duplicates(subset=['Codigo_Producto','Material'])
Producto_ = Producto_.drop_duplicates(subset=['Codigo_Producto','Material'])
Producto_
# Out:
#         Codigo_Producto                                           Material
# 0               8300003     Lejia Sapolio Original 5000 grs 4Bot - 8300003
# 1               4300008    Fid.Alianza Codo Rayado 250 grs 20Bol - 4300008
# 2               3101013  Nu. Aceite Veg. Primor Premium 1 lt 12 Bot - 3...
# 3               3101018  Aceite Prim Oliv Equilibrado 1 lt 12Botpet - 3...
# 4               8400550    Det Marsella Alegria Trop 750Gr.15Bol - 8400550
# ...                 ...                                                ...
# 594240          5101848      Gelatina Umsha Piña 120g 12Und 1Pqt - 5101848
# 612316          8315002  Lustramueb.Aceite Lim.Premio 300 ml 12Un - 831...
# 615752          5101852  Mazamorra Durazno Umsha 125g 12Und 1.25L - 510...
# 618047          8301123        Enj. Xtra Cool Dento 500 ml 12Und - 8301123
# 622614          8317021     Limpiatodo Bebe Sapolio 900 ml 12Und - 8317021
#
# [631 rows x 2 columns]

# %%
## Parte 2
Producto_ = Producto_.drop_duplicates(subset=['Codigo_Producto'])
x = pd.merge(Ventas_1, Producto_, left_on='Codigo',right_on='Codigo_Producto', how='outer')
x
# Out:
#          Codigo  Ventas sin IGV  Unidades B2B  Peso en Toneladas
# 0       8300003          165.71            19           0.095000  \
# 1       8300003          248.31            30           0.150000
# 2       8300003          549.94            64           0.320000
# 3       8300003          451.75            53           0.265000
# 4       8300003           34.40             4           0.020000
# ...         ...             ...           ...                ...
# 625429  5101852            5.60             2           0.000250
# 625430  8301123           11.44             1           0.000516
# 625431  8301123           11.44             1           0.000516
# 625432  8301123           11.44             1           0.000516
# 625433  8317021           10.65             4           0.003600
#
#         Codigo_Producto                                           Material
# 0               8300003     Lejia Sapolio Original 5000 grs 4Bot - 8300003
# ...
